# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
import statsmodels.api as sm
from statsmodels.tsa.api import SimpleExpSmoothing
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import acf, pacf
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('IBM_2006-01-01_to_2018-01-01.csv', parse_dates=['Date'])

# %%
df
# Out:
#            Date    Open    High     Low   Close    Volume Name
# 0    2006-01-03   82.45   82.55   80.81   82.06  11715200  IBM
# 1    2006-01-04   82.20   82.50   81.33   81.95   9840600  IBM
# 2    2006-01-05   81.40   82.90   81.00   82.50   7213500  IBM
# 3    2006-01-06   83.95   85.03   83.41   84.95   8197400  IBM
# 4    2006-01-09   84.10   84.25   83.38   83.73   6858200  IBM
# ...         ...     ...     ...     ...     ...       ...  ...
# 3015 2017-12-22  151.82  153.00  151.50  152.50   2990583  IBM
# 3016 2017-12-26  152.51  153.86  152.50  152.83   2479017  IBM
# 3017 2017-12-27  152.95  153.18  152.61  153.13   2149257  IBM
# 3018 2017-12-28  153.20  154.12  153.20  154.04   2687624  IBM
# 3019 2017-12-29  154.17  154.72  153.42  153.42   3327087  IBM
#
# [3020 rows x 7 columns]

# %%
df.index = df.Date
df.drop(['Date'], axis=1, inplace=True)

# %%
fig = plt.figure(figsize=(15, 4))
df.High.plot()

# %% [markdown]
# Разделение выборки на обучающую и тестовую

# %%
training_set = df[:'2016'].iloc[:, 1:2].values
test_set = df['2017':].iloc[:, 1:2].values

# %%
fig = plt.figure(figsize=(15, 4))
df.High[:'2016'].plot()
df.High['2017':].plot()

# %% [markdown]
# Автокорреляция

# %%
fig, ax = plt.subplots(figsize=(20, 8))
sm.graphics.tsa.plot_pacf(df.High.values, lags=48, ax=ax)
plt.show()

# %% [markdown]
# Нормируем данные

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %% [markdown]
# Строим признаки на снове сдвигов

# %%
shift_size = 30

X_train = []
y_train = []
for i in range(shift_size, len(training_set)):
    X_train.append(training_set_scaled[i-shift_size:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %% [markdown]
# Регрессор на базе градиентного бустинга

# %%
boost_regressor = XGBRegressor()
boost_regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#              validate_parameters=False, verbosity=None)

# %% [markdown]
# Подготовка тестовых данных

# %%
dataset_total = pd.concat((df.High[:'2016'], df.High['2017':]), axis=0)
inputs = dataset_total[len(dataset_total) - len(test_set) - shift_size:].values
inputs = inputs.reshape(-1, 1)
inputs  = sc.transform(inputs)

# %%
X_test = []
for i in range(shift_size, len(test_set) + shift_size):
    X_test.append(inputs[i - shift_size:i, 0])
X_test = np.array(X_test)

# %%
boost_pred = boost_regressor.predict(X_test)
boost_pred = sc.inverse_transform(boost_pred[:, np.newaxis])

# %%
fig, axes = plt.subplots(1, figsize=(20, 4))
axes.plot(test_set, color='red')
axes.plot(boost_pred, color='green')
axes.legend(['Answer', 'boost predict'])

# %% [markdown]
# Регрессор на основе случайного леса

# %%
rf_regressor = RandomForestRegressor()
rf_regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_pred = rf_regressor.predict(X_test)
rf_pred = sc.inverse_transform(rf_pred[:, np.newaxis])

# %%
fig, axes = plt.subplots(1, figsize=(20, 4))
axes.plot(test_set, color='red')
axes.plot(rf_pred, color='black')
axes.legend(['Answer', 'random forest predict'])

# %% [markdown]
# Простое экспоненциальное сглаживание

# %%
def exp_smoothing(train, test):
    forecast = []
    for i in range(len(test)):
        training_set = np.concatenate((train, test[:i]))
        fit = SimpleExpSmoothing(training_set).fit(smoothing_level=0.7, optimized=False)
        forecast.append(fit.forecast(1))
        
    return np.array(forecast)

# %%
exp_pred = exp_smoothing(training_set, test_set)

# %%
fig, axes = plt.subplots(1, figsize=(20, 4))
axes.plot(test_set, color='red')
axes.plot(exp_pred, color='brown')
axes.legend(['Answer', 'exp smoothing (1 step)'])

# %% [markdown]
# Преобразуем тестовые данные для входа нейросети (добавим размерность)

# %%
X_train = X_train[..., np.newaxis]

# %%
X_train.shape
# Out:
# (2739, 30, 1)

# %% [markdown]
# Построим модель из одного LSTM слоя с 500 нейронами и dropout с вероятностью 0.2 в качестве регуляризации нашей модели. <BR>Оптимизатор - **Adam**, лосс функция - **MSE**.
# <BR>Обучать будем 50 эпох, размер батча - 32

# %%
regressor = Sequential()

regressor.add(LSTM(units=500, input_shape=(X_train.shape[1], 1)))
regressor.add(Dropout(0.2))


regressor.add(Dense(units=1))

regressor.compile(optimizer='adam', loss='mean_squared_error')

regressor.fit(X_train, y_train, epochs=50, batch_size=32, workers=3, validation_data=[X_test[..., np.newaxis], test_set])
# Out:
# Train on 2739 samples, validate on 251 samples
# Epoch 1/50
# 2739/2739 [==============================] - 28s 10ms/step - loss: 0.0101 - val_loss: 25092.6986
# Epoch 2/50
# 2739/2739 [==============================] - 28s 10ms/step - loss: 9.1936e-04 - val_loss: 25085.5709
# Epoch 3/50
# 2739/2739 [==============================] - 28s 10ms/step - loss: 8.4430e-04 - val_loss: 25087.9660
# Epoch 4/50
# 2739/2739 [==============================] - 33s 12ms/step - loss: 8.0217e-04 - val_loss: 25081.0311
# Epoch 5/50
# 2739/2739 [==============================] - 29s 11ms/step - loss: 8.2532e-04 - val_loss: 25083.0450
# Epoch 6/50
# 2739/2739 [==============================] - 30s 11ms/step - loss: 8.2208e-04 - val_loss: 25081.0775
# Epoch 7/50
# 2739/2739 [==============================] - 28s 10ms/step - loss: 7.6642e-04 - val_loss: 25084.2970
# Epoch 8/50
# 2739/2739 [==============================] - 28s 10ms/step - loss: 7.7581e-04 - val_loss: 25083.5931
# Epoch 9/50
# 2739/2739 [==============================] - 32s 12ms/step - loss: 6.4551e-04 - val_loss: 25087.9938
# Epoch 10/50
# 2739/2739 [==============================] - 38s 14ms/step - loss: 6.7709e-04 - val_loss: 25083.6681
# Epoch 11/50
# 2739/2739 [==============================] - 37s 14ms/step - loss: 6.8805e-04 - val_loss: 25088.3076
# Epoch 12/50
# 2739/2739 [==============================] - 35s 13ms/step - loss: 6.3342e-04 - val_loss: 25090.4460
# 2739/2739 [==============================] - 27s 10ms/step - loss: 4.7568e-04 - val_loss: 25089.3152
# Epoch 41/50
# 2739/2739 [==============================] - 28s 10ms/step - loss: 4.2245e-04 - val_loss: 25084.2909
# Epoch 42/50
# 2739/2739 [==============================] - 31s 11ms/step - loss: 4.2549e-04 - val_loss: 25082.5795
# Epoch 43/50
# 2739/2739 [==============================] - 27s 10ms/step - loss: 4.0160e-04 - val_loss: 25084.0361
# Epoch 44/50
# 2739/2739 [==============================] - 27s 10ms/step - loss: 4.0727e-04 - val_loss: 25088.1779
# Epoch 45/50
# 2739/2739 [==============================] - 29s 10ms/step - loss: 4.2752e-04 - val_loss: 25081.0731
# Epoch 46/50
# 2739/2739 [==============================] - 26s 9ms/step - loss: 4.0642e-04 - val_loss: 25083.9686
# Epoch 47/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 3.9232e-04 - val_loss: 25079.5673
# Epoch 48/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 4.8460e-04 - val_loss: 25080.0650
# Epoch 49/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 4.2771e-04 - val_loss: 25082.3219
# Epoch 50/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 4.2138e-04 - val_loss: 25081.4366

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
lstm_pred = regressor.predict(X_test)
lstm_pred = sc.inverse_transform(lstm_pred)

# %%
fig, axes = plt.subplots(1, figsize=(20, 4))
axes.plot(test_set, color='red')
axes.plot(lstm_pred, color='blue')
axes.legend(['Answer', 'LSTM predict'])

# %% [markdown]
# Отрисуем все предсказания на графике

# %%
fig, axes = plt.subplots(1, figsize=(20, 4))
axes.plot(test_set, color='red', linewidth=3)
axes.plot(lstm_pred, color='blue')
axes.plot(boost_pred, color='green')
axes.plot(rf_pred, color='black')
axes.plot(exp_pred, color='brown')
axes.legend(['Answer', 'LSTM predict', 'boost predict', 'random forest', 'exponential smoothing'])

# %% [markdown]
# Посчитаем метрику MAPE для всех наших методов

# %%
import inspect

def retrieve_name(var):
    callers_local_vars = inspect.currentframe().f_back.f_locals.items()
    return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

def MAPE(y_true, y_pred):
    return (np.abs(y_true - y_pred) / y_true).sum() / y_true.shape[0] * 100

# %%
for predict in [boost_pred, rf_pred, exp_pred, lstm_pred]:
    print("{}: MAPE = {:.2}%".format(retrieve_name(predict), MAPE(test_set, predict)))
# Out:
# boost_pred: MAPE = 0.81%
# rf_pred: MAPE = 0.7%
# exp_pred: MAPE = 0.63%
# lstm_pred: MAPE = 1.3%

# %%
df = pd.read_csv('DailyDelhiClimateTrain.csv', parse_dates=['date'])

# %%
df
# Out:
#            date   meantemp    humidity  wind_speed  meanpressure
# 0    2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1    2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2    2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3    2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4    2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...         ...        ...         ...         ...           ...
# 1457 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
df.index = df.date
df.drop(['date'], axis=1, inplace=True)

# %%
df.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
fig = plt.figure(figsize=(15, 4))
df.meantemp.plot()

# %%
training_set = df[:'2015'].iloc[:, 0:1].values
test_set = df['2016':].iloc[:, 0:1].values

# %%
fig = plt.figure(figsize=(15, 4))
df.meantemp[:'2015'].plot()
df.meantemp['2016':].plot()

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
shift_size = 30

X_train = []
y_train = []
for i in range(shift_size, len(training_set)):
    X_train.append(training_set_scaled[i-shift_size:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
boost_regressor = XGBRegressor()
boost_regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#              validate_parameters=False, verbosity=None)

# %%
dataset_total = pd.concat((df.meantemp[:'2015'], df.meantemp['2016':]), axis=0)
inputs = dataset_total[len(dataset_total) - len(test_set) - shift_size:].values
inputs = inputs.reshape(-1, 1)
inputs  = sc.transform(inputs)

# %%
X_test = []
for i in range(shift_size, len(test_set) + shift_size):
    X_test.append(inputs[i - shift_size:i, 0])
X_test = np.array(X_test)

# %%
boost_pred = boost_regressor.predict(X_test)
boost_pred = sc.inverse_transform(boost_pred[:, np.newaxis])

# %%
fig, axes = plt.subplots(1, figsize=(20, 4))
axes.plot(test_set, color='red')
axes.plot(boost_pred, color='green')
axes.legend(['Answer', 'boost predict'])

# %%
rf_regressor = RandomForestRegressor()
rf_regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_pred = rf_regressor.predict(X_test)
rf_pred = sc.inverse_transform(rf_pred[:, np.newaxis])

# %%
fig, axes = plt.subplots(1, figsize=(20, 4))
axes.plot(test_set, color='red')
axes.plot(rf_pred, color='black')
axes.legend(['Answer', 'random forest predict'])

# %%
exp_pred = exp_smoothing(training_set, test_set)

# %%
fig, axes = plt.subplots(1, figsize=(20, 4))
axes.plot(test_set, color='red')
axes.plot(exp_pred, color='brown')
axes.legend(['Answer', 'exp smoothing (1 step)'])

# %%
X_train = X_train[..., np.newaxis]

# %%
X_train.shape
# Out:
# (1065, 30, 1)

# %%
regressor = Sequential()

regressor.add(LSTM(units=500, input_shape=(X_train.shape[1], 1)))
regressor.add(Dropout(0.2))


regressor.add(Dense(units=1))

regressor.compile(optimizer='adam', loss='mean_squared_error')

regressor.fit(X_train, y_train, epochs=50, batch_size=32, workers=3, validation_data=[X_test[..., np.newaxis], test_set])
# Epoch 30/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.0033 - val_loss: 742.8402
# Epoch 31/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.0035 - val_loss: 743.7342
# Epoch 32/50
# 1065/1065 [==============================] - 11s 11ms/step - loss: 0.0036 - val_loss: 741.4021
# Epoch 33/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.0034 - val_loss: 743.3504
# Epoch 34/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.0032 - val_loss: 744.2571
# Epoch 35/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.0033 - val_loss: 742.0787
# Epoch 36/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.0034 - val_loss: 742.8082
# Epoch 37/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.0032 - val_loss: 741.9249
# Epoch 38/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.0034 - val_loss: 741.9048
# Epoch 39/50
# 1065/1065 [==============================] - 11s 11ms/step - loss: 0.0032 - val_loss: 743.4624
# Epoch 40/50
# 1065/1065 [==============================] - 11s 11ms/step - loss: 0.0031 - val_loss: 744.0739
# Epoch 41/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.0031 - val_loss: 744.9861
# Epoch 42/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.0033 - val_loss: 742.9166
# Epoch 43/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.0029 - val_loss: 742.7692
# Epoch 44/50
# 1065/1065 [==============================] - 11s 11ms/step - loss: 0.0031 - val_loss: 743.3783
# Epoch 45/50
# 1065/1065 [==============================] - 11s 11ms/step - loss: 0.0033 - val_loss: 742.0301
# Epoch 46/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.0031 - val_loss: 741.4707
# Epoch 47/50
# 1065/1065 [==============================] - 11s 11ms/step - loss: 0.0031 - val_loss: 742.2482
# Epoch 48/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.0030 - val_loss: 743.7375
# Epoch 49/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.0030 - val_loss: 741.5548
# Epoch 50/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.0030 - val_loss: 742.2712

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
lstm_pred = regressor.predict(X_test)
lstm_pred = sc.inverse_transform(lstm_pred)

# %%
fig, axes = plt.subplots(1, figsize=(20, 4))
axes.plot(test_set, color='red')
axes.plot(lstm_pred, color='blue')
axes.legend(['Answer', 'LSTM predict', 'boost predict', 'random forest', 'exponential smoothing'])

# %%
fig, axes = plt.subplots(1, figsize=(20, 4))
axes.plot(test_set, color='red', linewidth=3)
axes.plot(lstm_pred, color='blue')
axes.plot(boost_pred, color='green')
axes.plot(rf_pred, color='black')
axes.plot(exp_pred, color='brown')
axes.legend(['Answer', 'LSTM predict', 'boost predict', 'random forest', 'exponential smoothing'])

# %%
for predict in [boost_pred, rf_pred, exp_pred, lstm_pred]:
    print("{}: MAPE = {:.2}%".format(retrieve_name(predict), MAPE(test_set, predict)))
# Out:
# boost_pred: MAPE = 5.5%
# rf_pred: MAPE = 5.1%
# exp_pred: MAPE = 5.1%
# lstm_pred: MAPE = 5.3%
