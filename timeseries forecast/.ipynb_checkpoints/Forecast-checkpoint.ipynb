# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
import statsmodels.api as sm
from statsmodels.tsa.api import SimpleExpSmoothing
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import acf, pacf

# %%
df = pd.read_csv('IBM_2006-01-01_to_2018-01-01.csv', parse_dates=['Date'])

# %%
df
# Out:
#            Date    Open    High     Low   Close    Volume Name
# 0    2006-01-03   82.45   82.55   80.81   82.06  11715200  IBM
# 1    2006-01-04   82.20   82.50   81.33   81.95   9840600  IBM
# 2    2006-01-05   81.40   82.90   81.00   82.50   7213500  IBM
# 3    2006-01-06   83.95   85.03   83.41   84.95   8197400  IBM
# 4    2006-01-09   84.10   84.25   83.38   83.73   6858200  IBM
# ...         ...     ...     ...     ...     ...       ...  ...
# 3015 2017-12-22  151.82  153.00  151.50  152.50   2990583  IBM
# 3016 2017-12-26  152.51  153.86  152.50  152.83   2479017  IBM
# 3017 2017-12-27  152.95  153.18  152.61  153.13   2149257  IBM
# 3018 2017-12-28  153.20  154.12  153.20  154.04   2687624  IBM
# 3019 2017-12-29  154.17  154.72  153.42  153.42   3327087  IBM
#
# [3020 rows x 7 columns]

# %%
df.index = df.Date
df.drop(['Date'], axis=1, inplace=True)

# %%
df.High.plot()

# %% [markdown]
# Разделение выборки на обучающую и тестовую

# %%
training_set = df[:'2016'].iloc[:, 1:2].values
test_set = df['2017':].iloc[:, 1:2].values

# %%
df.High[:'2016'].plot()
df.High['2017':].plot()

# %% [markdown]
# Автокорреляция

# %%
fig, ax = plt.subplots(figsize=(20, 8))
sm.graphics.tsa.plot_pacf(df.High.values, lags=48, ax=ax)
plt.show()

# %% [markdown]
# Нормируем данные

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %% [markdown]
# Строим признаки на снове сдвигов

# %%
shift_size = 30

X_train = []
y_train = []
for i in range(shift_size, len(training_set)):
    X_train.append(training_set_scaled[i-shift_size:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %% [markdown]
# Регрессор на базе градиентного бустинга

# %%
boost_regressor = XGBRegressor()
boost_regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#              validate_parameters=False, verbosity=None)

# %% [markdown]
# Подготовка тестовых данных

# %%
dataset_total = pd.concat((df.High[:'2016'], df.High['2017':]), axis=0)
inputs = dataset_total[len(dataset_total) - len(test_set) - shift_size:].values
inputs = inputs.reshape(-1, 1)
inputs  = sc.transform(inputs)

# %%
X_test = []
for i in range(shift_size, len(test_set) + shift_size):
    X_test.append(inputs[i - shift_size:i, 0])
X_test = np.array(X_test)

# %%
boost_pred = boost_regressor.predict(X_test)
boost_pred = sc.inverse_transform(boost_pred[:, np.newaxis])

# %%
fig, axes = plt.subplots(1)
axes.plot(test_set, color='red')
axes.plot(boost_pred, color='green')
axes.legend(['Answer', 'boost predict'])

# %% [markdown]
# Регрессор на основе случайного леса

# %%
rf_regressor = RandomForestRegressor()
rf_regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_pred = rf_regressor.predict(X_test)
rf_pred = sc.inverse_transform(rf_pred[:, np.newaxis])

# %%
fig, axes = plt.subplots(1)
axes.plot(test_set, color='red')
axes.plot(rf_pred, color='black')
axes.legend(['Answer', 'random forest predict'])

# %% [markdown]
# Простое экспоненциальное сглаживание

# %%
def exp_smoothing(train, test):
    forecast = []
    for i in range(len(test)):
        training_set = np.concatenate((train, test[:i]))
        fit = SimpleExpSmoothing(training_set).fit(smoothing_level=0.7, optimized=False)
        forecast.append(fit.forecast(1))
        
    return np.array(forecast)

# %%
exp_pred = exp_smoothing(training_set, test_set)

# %%
fig, axes = plt.subplots(1)
axes.plot(test_set, color='red')
axes.plot(exp_pred, color='brown')
axes.legend(['Answer', 'exp smoothing (1 step)'])

# %% [markdown]
# Преобразуем тестовые данные для входа нейросети (добавим размерность)

# %%
X_train = X_train[..., np.newaxis]

# %%
X_train.shape
# Out:
# (2739, 30, 1)

# %% [markdown]
# Построим модель из одного LSTM слоя с 500 нейронами и dropout с вероятностью 0.2 в качестве регуляризации нашей модели. <BR>Оптимизатор - **Adam**, лосс функция - **MSE**.
# <BR>Обучать будем 50 эпох, размер батча - 32

# %%
regressor = Sequential()

regressor.add(LSTM(units=500, input_shape=(X_train.shape[1], 1)))
regressor.add(Dropout(0.2))


regressor.add(Dense(units=1))

regressor.compile(optimizer='adam', loss='mean_squared_error')

regressor.fit(X_train, y_train, epochs=50, batch_size=32, workers=3)
# Out:
# Epoch 1/50
# 2739/2739 [==============================] - 36s 13ms/step - loss: 0.0161
# Epoch 2/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 9.4260e-04
# Epoch 3/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 8.9315e-04
# Epoch 4/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 8.4493e-04
# Epoch 5/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 8.4969e-04
# Epoch 6/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 9.2209e-04
# Epoch 7/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 7.7833e-04
# Epoch 8/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 8.0122e-04
# Epoch 9/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 7.7020e-04
# Epoch 10/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 7.1555e-04
# Epoch 11/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 7.1720e-04
# Epoch 12/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 7.5575e-04
# Epoch 13/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 7.2042e-04
# Epoch 14/50
# 2739/2739 [==============================] - 27s 10ms/step - loss: 6.5595e-04
# Epoch 15/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 6.7250e-04
# Epoch 16/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 6.2435e-04
# Epoch 17/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 6.1258e-04
# Epoch 18/50
# 2739/2739 [==============================] - 26s 9ms/step - loss: 6.6542e-04
# Epoch 19/50
# 2739/2739 [==============================] - 29s 11ms/step - loss: 6.1641e-04
# Epoch 20/50
# 2739/2739 [==============================] - 31s 11ms/step - loss: 5.8658e-04
# Epoch 21/50
# 2739/2739 [==============================] - 30s 11ms/step - loss: 5.8106e-04
# Epoch 22/50
# 2739/2739 [==============================] - 27s 10ms/step - loss: 6.0807e-04
# Epoch 23/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 6.1428e-04
# Epoch 24/50
# 2739/2739 [==============================] - 29s 11ms/step - loss: 5.5613e-04
# Epoch 25/50
# 2739/2739 [==============================] - 26s 10ms/step - loss: 5.3091e-04
# Epoch 26/50
# 2739/2739 [==============================] - 26s 10ms/step - loss: 6.0214e-04
# Epoch 27/50
# 2739/2739 [==============================] - 28s 10ms/step - loss: 5.6640e-04
# Epoch 28/50
# 2739/2739 [==============================] - 27s 10ms/step - loss: 4.7522e-04
# Epoch 29/50
# 2739/2739 [==============================] - 26s 10ms/step - loss: 5.1120e-04
# Epoch 30/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 5.4447e-04
# Epoch 31/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 5.1044e-04
# Epoch 32/50
# 2739/2739 [==============================] - 27s 10ms/step - loss: 4.8055e-04
# Epoch 33/50
# 2739/2739 [==============================] - 27s 10ms/step - loss: 4.8270e-04
# Epoch 34/50
# 2739/2739 [==============================] - 26s 9ms/step - loss: 4.3913e-04
# Epoch 35/50
# 2739/2739 [==============================] - 26s 9ms/step - loss: 4.8589e-04
# Epoch 36/50
# 2739/2739 [==============================] - 28s 10ms/step - loss: 4.9808e-04
# Epoch 37/50
# 2739/2739 [==============================] - 29s 11ms/step - loss: 5.1962e-04
# Epoch 38/50
# 2739/2739 [==============================] - 29s 11ms/step - loss: 4.5686e-04
# Epoch 39/50
# 2739/2739 [==============================] - 26s 10ms/step - loss: 4.5776e-04
# Epoch 40/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 4.8875e-04
# Epoch 41/50
# 2739/2739 [==============================] - 27s 10ms/step - loss: 4.5923e-04
# Epoch 42/50
# 2739/2739 [==============================] - 26s 9ms/step - loss: 4.0618e-04
# Epoch 43/50
# 2739/2739 [==============================] - 26s 9ms/step - loss: 4.5845e-04
# Epoch 44/50
# 2739/2739 [==============================] - 25s 9ms/step - loss: 5.0352e-04
# Epoch 45/50
# 2739/2739 [==============================] - 26s 10ms/step - loss: 4.3034e-04
# Epoch 46/50
# 2739/2739 [==============================] - 29s 11ms/step - loss: 4.3481e-04
# Epoch 47/50
# 2739/2739 [==============================] - 27s 10ms/step - loss: 4.1017e-04
# Epoch 48/50
# 2739/2739 [==============================] - 26s 10ms/step - loss: 3.8787e-04
# Epoch 49/50
# 2739/2739 [==============================] - 31s 11ms/step - loss: 3.6988e-04
# Epoch 50/50
# 2739/2739 [==============================] - 29s 11ms/step - loss: 3.9570e-04

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
lstm_pred = regressor.predict(X_test)
lstm_pred = sc.inverse_transform(lstm_pred)

# %% [markdown]
# Отрисуем все предсказания на графике

# %%
fig, axes = plt.subplots(1)
axes.plot(test_set, color='red', linewidth=3)
axes.plot(lstm_pred, color='blue')
axes.plot(boost_pred, color='green')
axes.plot(rf_pred, color='black')
axes.plot(exp_pred, color='brown')
axes.legend(['Answer', 'LSTM predict', 'boost predict', 'random forest', 'exponential smoothing'])

# %% [markdown]
# Посчитаем метрику MAPE для всех наших методов

# %%
import inspect

def retrieve_name(var):
    callers_local_vars = inspect.currentframe().f_back.f_locals.items()
    return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

def MAPE(y_true, y_pred):
    return (np.abs(y_true - y_pred) / y_true).sum() / y_true.shape[0] * 100

for predict in [boost_pred, rf_pred, exp_pred, lstm_pred]:
    print("{}: MAPE = {:.2}%".format(retrieve_name(predict), MAPE(test_set, predict)))
# Out:
# boost_pred: MAPE = 0.81%
# rf_pred: MAPE = 0.72%
# exp_pred: MAPE = 0.63%
# lstm_pred: MAPE = 0.68%
